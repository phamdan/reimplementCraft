# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
path='/content/gdrive/MyDrive/CRAFT-Reimplementation-master/eval'
os.chdir(path)
# !ls
# Out:
# gt.zip	     __pycache__  rrc_evaluation_funcs.py   script.py	Untitled0.ipynb
# __init__.py  readme.txt   rrc_evaluation_funcs.pyc  submit.zip

# %%
# !python
# Out:
# Traceback (most recent call last):
#   File "script.py", line 4, in <module>
#     from eval import rrc_evaluation_funcs
# ModuleNotFoundError: No module named 'eval'
